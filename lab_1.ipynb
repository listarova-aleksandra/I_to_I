# %% [markdown]
# <a href="https://colab.research.google.com/github/listarova-aleksandra/I_to_I/blob/main/lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 'Получение и предобработка данных'
# Ссылка на задания лабораторной:https://github.com/AnatoDu/Introduction_to_AI/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D1%8B%D0%B5%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D1%8B.pdf

# %%
import pandas as pd

# %% [markdown]
# ## Знакомство с библиотекой pandas

# %% [markdown]
# Создаю список music с парами «имя любимого исполнителя - название его
# песни».

# %%
music = [('Kendrick Lamar', 'Count Me Out'),
                ('Kanye West', 'Violent Crimes'),
                ('Tyler, The Creator', 'St.Chroma'),
                ('Frank Ocean', 'Solo'),
                ('SZA', 'Good Days')]

entries = ['artist', 'track']

# %% [markdown]
# Создаю таблицу из списка music со столбцами entries

# %%
playlist = pd.DataFrame(music, columns=entries)
playlist
# Out:
#                artist           track
# 0      Kendrick Lamar    Count Me Out
# 1          Kanye West  Violent Crimes
# 2  Tyler, The Creator       St.Chroma
# 3         Frank Ocean            Solo
# 4                 SZA       Good Days

# %%
df = pd.read_csv('music_log.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67963 entries, 0 to 67962
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0     user_id   67963 non-null  object
#  1   total play  67399 non-null  float64
#  2   Artist      59646 non-null  object
#  3   genre       64661 non-null  object
#  4   track       64804 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.6+ MB

# %%
music_head = df.head(5)
music_head
# Out:
#     user_id  total play        Artist    genre                   track
# 0  BF6EA5AF   92.851388    Marina Rei      pop                  Musica
# 1  FB1E568E  282.981000  Stive Morgan  ambient             Love Planet
# 2  FB1E568E  282.981000  Stive Morgan  ambient             Love Planet
# 3  EF15C7BA    8.966000           NaN    dance     Loving Every Minute
# 4  82F52E69  193.776327        Rixton      pop  Me And My Broken Heart

# %%
music_tail = df.tail(10)
music_tail
# Out:
#         user_id  total play        Artist   genre          track
# 67953  A06381D8    2.502000   Flip Grater    folk   My Old Shoes
# 67954  6E8E430E  139.627717       Alt & J  trance        Emotion
# 67955  D83CBA77  185.000000           TKN    rock    Не отступай
# 67956  816FBC10    2.000000         89ers   dance       Go Go Go
# 67957  18510741  109.000000   Steel Pulse  reggae  Chant A Psalm
# 67958  2E27DF51  220.551837  Nadine Coyle     pop  Girls On Fire
# 67959  4F29D4D5   26.127000  Digital Hero   dance      The Model
# 67960  26B7058C  292.455000       Red God   metal      Действуй!
# 67961  DB0038A8   11.529112  Less Chapell     pop           Home
# 67962  FE8684F6    0.100000           NaN     NaN            NaN

# %%
shape_table = df.shape
print(f'Размер таблицы: {shape_table}')
# Out:
# Размер таблицы: (67963, 5)

# %%
observations_table = shape_table[0]
print(f'Количество наблюдений: {observations_table}')
# Out:
# Количество наблюдений: 67963

# %%
observations_info_table = observations_table
if observations_info_table == observations_table:
    print(f'Решение верно, количество наблюдений равно {observations_table}')
else:
    print('Решение неверно, проверьте еще раз!')
# Out:
# Решение верно, количество наблюдений равно 67963

# %%
genre_fight = df[['genre', 'Artist']]
genre_pop = (df['genre'] == 'pop').sum()
print(f'Число прослушанных треков в жанре поп равно {genre_pop}')
# Out:
# Число прослушанных треков в жанре поп равно 8599

# %%
genre_rock = (df['genre'] == 'rock').sum()
print(f'Число прослушанных треков в жанре рок равно {genre_rock}')
# Out:
# Число прослушанных треков в жанре рок равно 6811

# %%
if genre_pop > genre_rock:
    print('Попса forever!')
elif genre_pop < genre_rock:
    print('Рок победил!')
else:
    print('Силы равны, но хип-хоп лучше!')
# Out:
# Попса forever!

# %%
rock = df[df['genre'] == 'rock']
rock_time = rock['total play']
